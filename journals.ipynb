# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt

import string
import nltk
from nltk.corpus import stopwords

# %%
data = pd.read_csv("intelligent and assistant.csv")

# %%
Articles = data[['Source title','Document Type']]

# %%
Articles = Articles.groupby('Document Type').get_group('Article')

# %%
source = pd.DataFrame(Articles['Source title'].value_counts())

# %%
source = source.reset_index()

# %%
source = source.rename(columns={'index':'Source title', 'Source title':'Count'})

# %%
source.head(8)
# Out:
#                                         Source title  Count
# 0                                        IEEE Access     28
# 1                     Applied Sciences (Switzerland)     13
# 2  Proceedings of the ACM on Human-Computer Inter...     11
# 3                                            Sensors     11
# 4                              Sensors (Switzerland)     10
# 5  International Journal of Human-Computer Intera...      8
# 6  IEEE Transactions on Intelligent Transportatio...      7
# 7                         Mobile Information Systems      7

# %%
counts = source.head(8)

# %%
plt.style.use('ggplot')
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.color'] = 'grey'

# %%
fig, ax = plt.subplots()
ax.barh(counts['Source title'], counts['Count'], color = 'black')

ax.set_title('Número de artículos por Journal')
ax.set_xlabel('Número de artículos')
ax.set_ylabel('Journal')

plt.show()
